# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/datos_grasas_Tec_limpio.csv")
data2 = pd.read_csv("../data/datos_grasas_Tec.csv", encoding="latin-1")

# %%
data2.columns
# Out:
# Index(['idDatosGrasas', 'codigoGrasa', 'Aceite Base', 'Espesante',
#        'Grado NLGI Consistencia', 'Viscosidad del Aceite Base a 40°C. cSt',
#        'Penetración de Cono a 25°C, 0.1mm', 'Punto de Gota, °C',
#        'Estabilidad Mecánica, %', 'Punto de Soldadura Cuatro Bolas, kgf',
#        'Desgaste Cuatro Bolas, mm', 'Indice de Carga-Desgaste',
#        'Carga Timken Ok, lb', 'Resistencia al Lavado por Agua a 80°C, %',
#        'Corrion EMCOR', 'Corrosión al Cobre', 'Prueba FZG', 'Registro NSF',
#        'Solidos Totales, %', 'Tamaño de Particula, µ', 'Bombeabilidad',
#        'Clasificacion ISO 6743-9', 'Presion de Flujo a -30°C, mbar',
#        'Separacion del Aceite, %', 'Prevencion a la Corrosion',
#        'Estabilidad a la Oxidacion', 'Resistencia a la Humedad', 'pH',
#        'Factor de Torque', 'Viscosidad Dinámica a 25°C, cP',
#        'Biodegradabilidad en 28 dias (> 60%)', 'Factor de Velocidad',
# ...

# %%
data.head()
# Out:
#    idDatosGrasas codigoGrasa     Aceite Base                        Espesante  \
# 0              1     Grasa_1  Semi-Sintetico     Complejo Sulfonato de Calcio
# 1              2     Grasa_2      Mineral HT     Complejo Sulfonato de Calcio
# 2              3     Grasa_3      Mineral HT     Complejo Sulfonato de Calcio
# 3              4     Grasa_4      Mineral HT     Complejo Sulfonato de Calcio
# 4              5     Grasa_5      Mineral HT  Complejo de Aluminio - Poliurea
#
#    Grado NLGI Consistencia  Viscosidad del Aceite Base a 40°C. cSt  \
# 0                      2.0                                   680.0
# 1                      1.5                                   460.0
# 2                      2.0                                   460.0
# 3                      2.0                                   220.0
# 4                      1.5                                   680.0
#
#   Penetración de Cono a 25°C, 0.1mm Punto de Gota, °C Estabilidad Mecánica, %  \
# ...

# %%
data.columns
# Out:
# Index(['idDatosGrasas', 'codigoGrasa', 'Aceite Base', 'Espesante',
#        'Grado NLGI Consistencia', 'Viscosidad del Aceite Base a 40°C. cSt',
#        'Penetración de Cono a 25°C, 0.1mm', 'Punto de Gota, °C',
#        'Estabilidad Mecánica, %', 'Punto de Soldadura Cuatro Bolas, kgf',
#        'Desgaste Cuatro Bolas, mm', 'Indice de Carga-Desgaste',
#        'Carga Timken Ok, lb', 'Resistencia al Lavado por Agua a 80°C, %',
#        'Corrosión al Cobre', 'Registro NSF', 'Factor de Velocidad',
#        'Temperatura de Servicio °C, min', 'Temperatura de Servicio °C, max',
#        'categoria', 'subtitulo', 'descripcion', 'beneficios', 'aplicaciones',
#        'color', 'textura'],
#       dtype='object')

# %%
df_solo_numerico = data.select_dtypes(include=np.number)

# %%
df_solo_numerico.head()
# Out:
#    idDatosGrasas  Grado NLGI Consistencia  \
# 0              1                      2.0
# 1              2                      1.5
# 2              3                      2.0
# 3              4                      2.0
# 4              5                      1.5
#
#    Viscosidad del Aceite Base a 40°C. cSt  \
# 0                                   680.0
# 1                                   460.0
# 2                                   460.0
# 3                                   220.0
# 4                                   680.0
#
#    Punto de Soldadura Cuatro Bolas, kgf  Desgaste Cuatro Bolas, mm  \
# 0                                 500.0                        NaN
# 1                                 900.0                       0.50
# 2                                 500.0                       0.48
# 3                                 500.0                       0.45
# 4                                 620.0                       0.48
#
# ...

# %%
data.describe()
# Out:
#        idDatosGrasas  Grado NLGI Consistencia  \
# count      51.000000                51.000000
# mean       26.000000                 1.523529
# std        14.866069                 0.834407
# min         1.000000                 0.000000
# 25%        13.500000                 1.000000
# 50%        26.000000                 1.500000
# 75%        38.500000                 2.000000
# max        51.000000                 3.000000
#
#        Viscosidad del Aceite Base a 40°C. cSt  \
# count                               50.000000
# mean                               579.600000
# std                                734.163303
# min                                 40.000000
# 25%                                120.000000
# 50%                                430.000000
# 75%                                680.000000
# max                               3800.000000
#
#        Punto de Soldadura Cuatro Bolas, kgf  Desgaste Cuatro Bolas, mm  \
# ...

# %%
df_solo_numerico.columns
# Out:
# Index(['idDatosGrasas', 'Grado NLGI Consistencia',
#        'Viscosidad del Aceite Base a 40°C. cSt',
#        'Punto de Soldadura Cuatro Bolas, kgf', 'Desgaste Cuatro Bolas, mm',
#        'Indice de Carga-Desgaste', 'Registro NSF', 'Factor de Velocidad',
#        'Temperatura de Servicio °C, min', 'Temperatura de Servicio °C, max'],
#       dtype='object')

# %%
list = [[1,460,620,0.31,"NaN","NaN","NaN","NaN"],[2,460,620,0.31,"NaN","NaN","NaN","NaN"],
        ["NaN",95,408,"NaN","NaN",-20,160],["NaN",226,315,0.45,107,"NaN",-40,132],
        ["NaN",226,315,0.45,107,"NaN",-40,132], ["NaN",226,315,0.45,107,"NaN",-40,177],
        ["NaN",226,315,0.45,107,"NaN",-40,177], ["NaN",220,400,0.43,72,"NaN",-40,177],
        ["NaN",220,400,0.43,72,"NaN",-40,177], ["NaN",220,315,0.45,50,"NaN",-40,132],
        ["NaN",220,315,0.45,50,"NaN",-40,177]]

# Primera: Cogelsa 1, Segunda: Cogelsa 2, Tercera: AnderolFgss2, Cuarta: Chevron greaseEP00
# Quinta: Chevron greaseEP0, Sexta: Chevron greaseEP1, Septima: Chevron greaseEP2, OCtava StarplexEp1M3
# Novena: StarplexEp2M3, Decima: StarplexEp00, Once: StarplexEp1
